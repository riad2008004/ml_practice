# %%
from ultralytics import YOLO

# %%
model=YOLO('yolov8n.yaml')

# %%
model.train(
    data='E:/Codes/machine_learning/image_processing/qr_codes/data.yaml',  # Path to your dataset configuration YAML file
    epochs=1,     # Set the number of epochs you want to train for
    batch=16,     # Batch size (adjust based on your hardware capabilities)
    imgsz=640,    # Input image size (adjust as needed)
    project='.',  # Save results in the current directory
    name='custom_yolov8_model'  # Name of the folder to save the model
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.82 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.81  Python-3.12.4 torch-2.6.0+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# ...
